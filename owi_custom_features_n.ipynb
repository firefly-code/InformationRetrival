# %%
import pyterrier as pt
import ir_datasets
import os
import matplotlib.pyplot as plt
import ir_datasets_owi

# %%
pt.init()
ir_datasets_owi.register()
# Out:
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# /var/folders/84/d6q_x_ds1db6rwg5hsq2s2p80000gn/T/ipykernel_98700/2762994459.py:1: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# java is now started automatically with default settings. To force initialisation early, run:
# pt.java.init() # optional, forces java initialisation
#   pt.init()

# %%
#ds = pt.get_dataset("irds:disks45/nocr/trec-robust-2004")
ds = pt.get_dataset("irds:owi/subsampled/dev")
print(ds)

INDEX_DIR = "./new_owi_index_customfeatures"
os.makedirs(INDEX_DIR, exist_ok=True)

INDEX_DIR = os.path.abspath("./new_owi_index_customfeatures")
# Out:
# IRDSDataset('owi/subsampled/dev')

# %% [markdown]
# ## new index part

# %% [markdown]
# load index

# %%
index = pt.IndexFactory.of(INDEX_DIR)
# Out:
# 17:36:56.777 [main] WARN org.terrier.structures.BaseCompressingMetaIndex -- Structure meta reading data file directly from disk (SLOW) - try index.meta.data-source=fileinmem in the index properties file. 589,4 MiB of memory would be required.

# %% [markdown]
# create index

# %%
# META_FIELD_LENGTHS = {"docno": 65, "main_content": 10000}
# INDEXER_PROPERTIES = {"meta.reverse.keys": "docno,main_content"}

# indexer = pt.IterDictIndexer(
#     INDEX_DIR,
#     text_attrs = ['main_content'],
#     meta = META_FIELD_LENGTHS,
#     properties = INDEXER_PROPERTIES
# )

# index_ref = indexer.index(ds.get_corpus_iter())
# index = pt.IndexFactory.of(index_ref)
# Out:
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# 16:01:09.041 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# 16:01:09.041 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15783/357212 [00:33<15:59, 355.77it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# 16:01:09.041 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15783/357212 [00:33<15:59, 355.77it/s]
# 16:01:10.199 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.070 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.070 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.129 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.129 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.188 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.188 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.051 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.051 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# 16:01:09.041 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15783/357212 [00:33<15:59, 355.77it/s]
# 16:01:10.199 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.070 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.070 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.129 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.129 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.188 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.188 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.051 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.051 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   5%|▍         | 16725/357212 [00:35<14:20, 395.85it/s]
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# 16:01:09.041 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.098 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:09.492 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.007 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:10.067 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15783/357212 [00:33<15:59, 355.77it/s]
# 16:01:10.199 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.070 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.070 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.129 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.129 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.188 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:11.188 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.051 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.051 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   5%|▍         | 16725/357212 [00:35<14:20, 395.85it/s]
# 16:01:12.521 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.994 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:12.994 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:13.050 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:13.050 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:13.103 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:13.103 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:00:36.888 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- creating the data structures data_stream0_1
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# 16:00:36.890 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 16:00:36.893 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (007698c09ce79e16134423dc9b39adc2ebe8689889d8cf8622475b12d2f93079) - further warnings are suppressed
# owi/subsampled/dev documents:   0%|          | 185/357212 [00:00<09:56, 598.99it/s]
# 16:01:04.937 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:05.152 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14141/357212 [00:28<15:28, 369.55it/s]
# 16:01:06.046 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.355 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14428/357212 [00:29<17:51, 319.92it/s]
# 16:01:06.714 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:06.787 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:07.168 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 14879/357212 [00:30<16:06, 354.36it/s]
# 16:01:07.762 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.177 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:08.342 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   4%|▍         | 15154/357212 [00:31<17:04, 333.91it/s]
# ...
# 16:01:30.367 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:30.427 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:01:30.427 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:   7%|▋         | 25893/357212 [00:54<11:28, 480.88it/s]
# 16:02:02.940 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  12%|█▏        | 42716/357212 [01:27<12:58, 403.93it/s]
# 16:02:07.472 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:07.535 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:07.535 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:07.587 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:07.587 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:07.885 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:07.885 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  12%|█▏        | 44333/357212 [01:31<12:41, 411.06it/s]
# 16:02:09.161 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:09.236 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:09.236 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:09.288 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:09.288 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  13%|█▎        | 45221/357212 [01:33<11:29, 452.36it/s]
# 16:02:10.040 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:10.338 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:10.338 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  13%|█▎        | 45684/357212 [01:34<10:54, 476.30it/s]
# 16:02:11.003 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:11.283 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:11.283 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  13%|█▎        | 46102/357212 [01:34<10:57, 472.92it/s]
# 16:02:11.708 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:11.782 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:11.782 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:11.838 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:11.838 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:12.205 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:12.205 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:12.684 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:12.684 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  13%|█▎        | 46678/357212 [01:36<10:58, 471.93it/s]
# 16:02:13.709 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:13.769 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:13.769 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:14.128 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:14.128 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  13%|█▎        | 47308/357212 [01:37<11:08, 463.81it/s]
# 16:02:14.772 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:14.834 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:14.834 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  13%|█▎        | 47666/357212 [01:38<11:35, 444.85it/s]
# 16:02:15.936 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:15.994 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:15.994 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  14%|█▎        | 48329/357212 [01:39<11:07, 462.54it/s]
# 16:02:16.661 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:17.410 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:17.410 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:17.468 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:17.468 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  14%|█▎        | 48896/357212 [01:40<10:48, 475.12it/s]
# 16:02:18.977 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:19.507 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:02:19.507 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  14%|█▍        | 49915/357212 [01:43<10:59, 465.89it/s]
# 16:03:06.285 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  21%|██        | 73952/357212 [02:29<11:59, 393.50it/s]
# 16:03:06.866 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:03:06.921 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:03:06.921 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  21%|██        | 74477/357212 [02:31<11:18, 416.51it/s]
# 16:03:08.283 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  21%|██        | 74988/357212 [02:32<10:42, 439.58it/s]
# 16:03:12.681 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  22%|██▏       | 76999/357212 [02:36<10:18, 452.82it/s]
# 16:03:13.253 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  22%|██▏       | 77649/357212 [02:37<09:39, 482.70it/s]
# 16:04:28.025 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  29%|██▉       | 102737/357212 [03:54<15:54, 266.74it/s]
# 16:04:32.209 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  29%|██▉       | 103632/357212 [03:57<15:19, 275.86it/s]
# 16:06:44.296 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  41%|████      | 145704/357212 [06:08<12:03, 292.31it/s]
# 16:07:05.263 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  43%|████▎     | 152116/357212 [06:29<11:59, 285.05it/s]
# 16:07:45.856 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:09:19.463 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  54%|█████▍    | 194401/357212 [08:43<09:32, 284.28it/s]
# 16:11:10.639 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  64%|██████▍   | 229307/357212 [10:34<07:10, 297.06it/s]
# 16:11:12.607 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  64%|██████▍   | 229993/357212 [10:37<07:19, 289.64it/s]
# 16:12:09.822 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:12:11.008 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:12:11.008 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  69%|██████▉   | 247522/357212 [11:35<06:50, 267.26it/s]
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# owi/subsampled/dev documents:  70%|███████   | 250582/357212 [11:44<05:46, 307.95it/s]
# 16:13:22.386 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:13:22.499 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:13:22.499 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  76%|███████▌  | 269862/357212 [12:47<05:26, 267.92it/s]
# 16:15:07.377 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  85%|████████▍ | 303345/357212 [14:33<03:18, 271.72it/s]
# 16:15:35.630 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:15:36.873 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:15:36.873 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:15:37.002 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:15:37.002 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:15:38.115 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:15:38.115 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  87%|████████▋ | 312002/357212 [15:01<02:54, 259.00it/s]
# 16:15:42.513 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  88%|████████▊ | 313593/357212 [15:07<02:45, 264.18it/s]
# 16:17:24.870 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:17:26.124 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# 16:17:26.124 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  97%|█████████▋| 345092/357212 [16:50<00:50, 239.67it/s]
# 16:17:28.339 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents:  97%|█████████▋| 347036/357212 [16:55<00:35, 284.84it/s]
# 16:17:42.811 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.collections.FSOrderedMapFile -- Flush forced
# owi/subsampled/dev documents: 100%|██████████| 357212/357212 [17:27<00:00, 341.11it/s]
# 16:18:05.321 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.BaseMetaIndexBuilder -- ZstdMetaIndexBuilder meta achieved compression ratio 17.455055 (> 1 is better)
# 16:18:05.609 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- 222 lexicons to merge
# 16:18:05.609 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- 222 lexicons to merge
# 16:18:16.277 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- Optimising structure lexicon
# 16:18:16.278 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.FSOMapFileLexiconUtilities -- Optimising lexicon with 3932782 entries
# 16:18:16.277 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- Optimising structure lexicon
# 16:18:16.278 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.FSOMapFileLexiconUtilities -- Optimising lexicon with 3932782 entries
# 16:18:17.485 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Started building the inverted index...
# 16:18:17.488 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.classical.InvertedIndexBuilder -- BasicMemSizeLexiconScanner: lexicon scanning until approx 2,9 GiB of memory is consumed
# 16:18:17.489 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.classical.InvertedIndexBuilder -- Iteration 1 of 1 (estimated) iterations
# 16:18:17.485 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Started building the inverted index...
# 16:18:17.488 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.classical.InvertedIndexBuilder -- BasicMemSizeLexiconScanner: lexicon scanning until approx 2,9 GiB of memory is consumed
# 16:18:17.489 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.classical.InvertedIndexBuilder -- Iteration 1 of 1 (estimated) iterations
# 16:18:36.662 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- Optimising structure lexicon
# 16:18:36.663 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.FSOMapFileLexiconUtilities -- Optimising lexicon with 3932782 entries
# 16:18:36.662 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.LexiconBuilder -- Optimising structure lexicon
# 16:18:36.663 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.FSOMapFileLexiconUtilities -- Optimising lexicon with 3932782 entries
# 16:18:37.776 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Finished building the inverted index...
# 16:18:37.777 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Time elapsed for inverted file: 20
# 16:18:37.778 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Collection took 1080 seconds to index (357212 documents)
# 16:18:37.779 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Indexed 12028 empty documents
# 16:18:37.776 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Finished building the inverted index...
# 16:18:37.777 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Time elapsed for inverted file: 20
# 16:18:37.778 [ForkJoinPool-5-worker-1] INFO org.terrier.structures.indexing.Indexer -- Collection took 1080 seconds to index (357212 documents)
# 16:18:37.779 [ForkJoinPool-5-worker-1] WARN org.terrier.structures.indexing.Indexer -- Indexed 12028 empty documents

# %%
print(index.getCollectionStatistics())
# Out:
# Number of documents: 357212
# Number of terms: 3932782
# Number of postings: 94259835
# Number of fields: 0
# Number of tokens: 562115239
# Field names: []
# Positions:   false

# %%
meta_index = index.getMetaIndex()

print(meta_index.getKeys())
print(list(meta_index.getReverseKeys()))
# Out:
# ['docno', 'main_content']
# ['docno']

# %% [markdown]
# ## XG Boost Part

# %%
import os
import pyterrier as pt
import pandas as pd
import xgboost as xgb
import re

# %%
#Function 1
def count_term_in_body_unique(row, meta_index):
    """
    Counts how many unique terms in the query appear in the document body.
    """
    docno = row["docno"]
    docid = meta_index.getDocument("docno", docno)

    if docid == -1:
        return 0

    body = meta_index.getItem("main_content", docid)

    body_terms = set(body.lower().split())
    query_terms = set(row["query"].lower().split())

    count = sum(1 for term in query_terms if term in body_terms)
    return count

# %%
#Function 2
def count_term_in_body_full(row, meta_index):
    """
    Counts the total occurrences of query terms in the document body.
    """
    docno = row["docno"]
    docid = meta_index.getDocument("docno", docno)

    if docid == -1:
        return 0

    body = meta_index.getItem("main_content", docid) or ""

    body_terms = body.lower().split()
    query_terms = row["query"].lower().split()

    # Count total occurrences
    count = sum(body_terms.count(term) for term in query_terms)
    return count

# %%
#Function3 
def query_coverage_first_200(row, meta_index):
    docno = row["docno"]
    docid = meta_index.getDocument("docno", docno)
    if docid == -1:
        return 0.0
    
    body = meta_index.getItem("main_content", docid) or ""

    body_terms = body.lower().split()[:200]
    query_terms = row["query"].lower().split()
    if not query_terms:
        return 0.0
    
    matched_terms = sum(1 for term in query_terms if term in body_terms)
    return float(matched_terms / len(query_terms))

# %%
#Fuction 4 
def count_doc_length(row, meta_index):
    """
    Counts the total number of words in the document body.
    """
    docno = row["docno"]
    docid = meta_index.getDocument("docno", docno)

    if docid == -1:
        return 0

    body = meta_index.getItem("main_content", docid) or ""

    return len(body.split())

# %%
#Function 5 
def count_query_length(row, meta_index=None):
    """
    Counts the total number of words in the query.
    """
    query = row["query"] or ""
    return len(query.split())

# %%
#Function 6 
def query_document_length_ratio(row, meta_index):
    """
    Computes the ratio: document_length / query_length.
    """
    docno = row["docno"]
    docid = meta_index.getDocument("docno", docno)

    if docid == -1:
        return 0

    body = meta_index.getItem("main_content", docid) or ""
    doc_length = len(body.split())

    query = row["query"] or ""
    query_length = len(query.split())

    if query_length == 0:
        return 0

    return doc_length / query_length

# %%
#Function 7 
def first_query_term_position(row, meta_index):
    """
    Returns the first position (0-based index) of any query term in the document body.
    """
    docno = row["docno"]
    docid = meta_index.getDocument("docno", docno)

    if docid == -1:
        return -1

    body = meta_index.getItem("main_content", docid) or ""
    body_terms = body.lower().split()

    query_terms = set(row["query"].lower().split())

    for i, term in enumerate(body_terms):
        if term in query_terms:
            return i

    return -1

# %%
#Testing some functions on an example:
docid = 0
body = meta_index.getItem("main_content", docid)
docno = meta_index.getItem("docno", docid)

# print("DOCNO:", docno)
# print("BODY:", body[:300])

test_row = {
    "docno": docno,
    "query": "example query relative. the and"
}


count_unique = count_term_in_body_unique(test_row, meta_index)
print("\nNumber of unique query terms in document:", count_unique)

count_full = count_term_in_body_full(test_row, meta_index)
print("\nNumber of query terms in document in total:", count_full)
# Out:
# Number of unique query terms in document: 2
#
# Number of query terms in document in total: 76

# %%
# Creating format for the pipeline  

custom_feature_transformer_unique = pt.apply.doc_score(
    lambda row: count_term_in_body_unique(row, meta_index)
)

custom_feature_transformer_full = pt.apply.doc_score(
    lambda row: count_term_in_body_full(row, meta_index)
)

custom_feature_coverage_200 = pt.apply.doc_score(
    lambda row: query_coverage_first_200(row, meta_index)
)

custom_feature_coverage_doc_length = pt.apply.doc_score(
    lambda row: count_doc_length(row, meta_index)
)

custom_feature_coverage_query_length = pt.apply.doc_score(
    lambda row: count_query_length(row, meta_index)
)

custom_feature_ratio = pt.apply.doc_score(
    lambda row: query_document_length_ratio(row, meta_index)
)

custom_feature_first_match = pt.apply.doc_score(
    lambda row: first_query_term_position(row, meta_index)
)

# %%
pt.terrier.set_property("index.meta.data-source", "fileinmem")   #for speed 
pt.terrier.set_property("indexer.meta.forward.keylens.docno", "65")
pt.terrier.set_property("indexer.meta.forward.keylens.main_content", "10000") 

topics = ds.get_topics().rename(columns={"title": "query"})
topics["query"] = topics["query"].apply(lambda x: re.sub(r'[^A-Za-z0-9 ]+', ' ', x))
qrels = ds.get_qrels()

#train-validation split 
split = int(len(topics) * 0.8)
train_topics = topics.iloc[:split]
valid_topics = topics.iloc[split:]
train_qrels = qrels[qrels["qid"].isin(train_topics["qid"])]
valid_qrels = qrels[qrels["qid"].isin(valid_topics["qid"])]

#base retrievers 
pt.logging("INFO")
bm25 = pt.terrier.Retriever(index, wmodel="BM25")
#tf = pt.terrier.Retriever(index_ref, wmodel="Tf")    
pl2 = pt.terrier.Retriever(index, wmodel="PL2")  

#candiate retrieval using base retrievers 
candidate_retrieval = (bm25 % 100) | (pl2 % 100) #| (tf % 100) |

bm25_scorer = pt.terrier.Retriever(index, wmodel="BM25")
tf_scorer = pt.terrier.Retriever(index, wmodel="Tf")
pl2_scorer = pt.terrier.Retriever(index, wmodel="PL2")


features = []

pipeline = (candidate_retrieval 
            >> pt.text.get_text(index, "main_content") 
            >>  (
                bm25_scorer 
                ** tf_scorer
                ** pl2_scorer 
                ** custom_feature_transformer_unique 
                ** custom_feature_transformer_full
                ** custom_feature_coverage_200
                ** custom_feature_coverage_doc_length
                ** custom_feature_coverage_query_length
                ** custom_feature_ratio
                ** custom_feature_first_match
                )
            )

xgb_ranker = xgb.XGBRanker(
    objective="rank:ndcg",
    learning_rate=0.1,
    gamma=1.0,
    min_child_weight=0.1,
    max_depth=6,
    random_state=42
)
# Out:
# /var/folders/84/d6q_x_ds1db6rwg5hsq2s2p80000gn/T/ipykernel_98700/1100903036.py:17: DeprecationWarning: Call to deprecated function (or staticmethod) set_log_level. (use pt.java.set_log_level(...) instead) -- Deprecated since version 0.11.0.
#   pt.logging("INFO")

# %%
ltr_pipeline = pipeline >> pt.ltr.apply_learned_model(xgb_ranker, form="ltr")

ltr_pipeline.fit(train_topics, train_qrels, valid_topics, valid_qrels)
# Out:
# 17:42:23.926 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 3 - split ergo keyboard
# 17:42:23.928 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:23.929 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:23.930 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:23.932 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:23.933 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:23.934 [main] INFO org.terrier.querying.LocalManager -- split { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6236eb5f] tags=[firstmatchscore]} ergo { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7c1e2a9e] tags=[firstmatchscore]} keyboard { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@fa36558] tags=[firstmatchscore]}
# 17:42:23.928 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:23.929 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:23.930 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:23.932 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:23.933 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:23.934 [main] INFO org.terrier.querying.LocalManager -- split { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6236eb5f] tags=[firstmatchscore]} ergo { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7c1e2a9e] tags=[firstmatchscore]} keyboard { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@fa36558] tags=[firstmatchscore]}
# 17:42:23.938 [main] INFO org.terrier.matching.PostingListManager -- Query 3 with 3 terms has 3 posting lists
# 17:42:23.940 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:23.940 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:23.938 [main] INFO org.terrier.matching.PostingListManager -- Query 3 with 3 terms has 3 posting lists
# 17:42:23.940 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:23.940 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.039 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 3 in 113ms - 1000 results retrieved
# 17:42:24.049 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 4 - metoo hollywood
# 17:42:24.039 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 3 in 113ms - 1000 results retrieved
# 17:42:24.049 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 4 - metoo hollywood
# 17:42:24.050 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.050 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.051 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.051 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.052 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.052 [main] INFO org.terrier.querying.LocalManager -- metoo { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@672872e1] tags=[firstmatchscore]} hollywood { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@32910148] tags=[firstmatchscore]}
# 17:42:24.056 [main] INFO org.terrier.matching.PostingListManager -- Query 4 with 2 terms has 2 posting lists
# 17:42:24.057 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.057 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.050 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.050 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.051 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.051 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.052 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.052 [main] INFO org.terrier.querying.LocalManager -- metoo { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@672872e1] tags=[firstmatchscore]} hollywood { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@32910148] tags=[firstmatchscore]}
# 17:42:24.056 [main] INFO org.terrier.matching.PostingListManager -- Query 4 with 2 terms has 2 posting lists
# 17:42:24.057 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.057 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.155 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 4 in 106ms - 1000 results retrieved
# 17:42:24.165 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 7 - gastritis symptoms
# 17:42:24.155 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 4 in 106ms - 1000 results retrieved
# 17:42:24.165 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 7 - gastritis symptoms
# 17:42:24.166 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.166 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.167 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.167 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.168 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.169 [main] INFO org.terrier.querying.LocalManager -- gastriti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3f56875e] tags=[firstmatchscore]} symptom { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2b4bac49] tags=[firstmatchscore]}
# 17:42:24.172 [main] INFO org.terrier.matching.PostingListManager -- Query 7 with 2 terms has 2 posting lists
# 17:42:24.173 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.174 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.166 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.166 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.167 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.167 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.168 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.169 [main] INFO org.terrier.querying.LocalManager -- gastriti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3f56875e] tags=[firstmatchscore]} symptom { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2b4bac49] tags=[firstmatchscore]}
# 17:42:24.172 [main] INFO org.terrier.matching.PostingListManager -- Query 7 with 2 terms has 2 posting lists
# 17:42:24.173 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.174 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.274 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 7 in 109ms - 1000 results retrieved
# 17:42:24.284 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 8 - what is privacy by design pbd
# 17:42:24.274 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 7 in 109ms - 1000 results retrieved
# 17:42:24.284 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 8 - what is privacy by design pbd
# 17:42:24.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.286 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.286 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.287 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.288 [main] INFO org.terrier.querying.LocalManager -- privaci { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@fd07cbb] tags=[firstmatchscore]} design { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3571b748] tags=[firstmatchscore]} pbd { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3e96bacf] tags=[firstmatchscore]}
# 17:42:24.292 [main] INFO org.terrier.matching.PostingListManager -- Query 8 with 3 terms has 3 posting lists
# 17:42:24.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.286 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.286 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.287 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.288 [main] INFO org.terrier.querying.LocalManager -- privaci { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@fd07cbb] tags=[firstmatchscore]} design { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3571b748] tags=[firstmatchscore]} pbd { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3e96bacf] tags=[firstmatchscore]}
# 17:42:24.292 [main] INFO org.terrier.matching.PostingListManager -- Query 8 with 3 terms has 3 posting lists
# 17:42:24.298 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.298 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.298 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.298 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.390 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 8 in 106ms - 1000 results retrieved
# 17:42:24.401 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 13 - impact of exercise on depression
# 17:42:24.390 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 8 in 106ms - 1000 results retrieved
# 17:42:24.401 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 13 - impact of exercise on depression
# 17:42:24.402 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.402 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.402 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.403 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.404 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.405 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.406 [main] INFO org.terrier.querying.LocalManager -- impact { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@484970b0] tags=[firstmatchscore]} exercis { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4470f8a6] tags=[firstmatchscore]} depress { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7c83dc97] tags=[firstmatchscore]}
# 17:42:24.409 [main] INFO org.terrier.matching.PostingListManager -- Query 13 with 3 terms has 3 posting lists
# 17:42:24.402 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.403 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.404 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.405 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.406 [main] INFO org.terrier.querying.LocalManager -- impact { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@484970b0] tags=[firstmatchscore]} exercis { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4470f8a6] tags=[firstmatchscore]} depress { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7c83dc97] tags=[firstmatchscore]}
# 17:42:24.409 [main] INFO org.terrier.matching.PostingListManager -- Query 13 with 3 terms has 3 posting lists
# 17:42:24.414 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.415 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.414 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.415 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.540 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 13 in 139ms - 1000 results retrieved
# 17:42:24.540 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 13 in 139ms - 1000 results retrieved
# 17:42:24.551 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 15 - autonomous car ethics in unavoidable accidents
# 17:42:24.551 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.552 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.552 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.553 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.553 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.554 [main] INFO org.terrier.querying.LocalManager -- autonom { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7748410a] tags=[firstmatchscore]} car { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@740773a3] tags=[firstmatchscore]} ethic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@37f1104d] tags=[firstmatchscore]} unavoid { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@55740540] tags=[firstmatchscore]} accid { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@60015ef5] tags=[firstmatchscore]}
# 17:42:24.560 [main] INFO org.terrier.matching.PostingListManager -- Query 15 with 5 terms has 5 posting lists
# 17:42:24.551 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 15 - autonomous car ethics in unavoidable accidents
# 17:42:24.551 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.552 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.552 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.553 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.553 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.554 [main] INFO org.terrier.querying.LocalManager -- autonom { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7748410a] tags=[firstmatchscore]} car { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@740773a3] tags=[firstmatchscore]} ethic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@37f1104d] tags=[firstmatchscore]} unavoid { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@55740540] tags=[firstmatchscore]} accid { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@60015ef5] tags=[firstmatchscore]}
# 17:42:24.560 [main] INFO org.terrier.matching.PostingListManager -- Query 15 with 5 terms has 5 posting lists
# 17:42:24.564 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.564 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.564 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.564 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.648 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 15 in 97ms - 1000 results retrieved
# 17:42:24.658 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 16 - mahler sixth symphony concert 2025
# 17:42:24.648 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 15 in 97ms - 1000 results retrieved
# 17:42:24.658 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 16 - mahler sixth symphony concert 2025
# 17:42:24.659 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.659 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.660 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.660 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.661 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.662 [main] INFO org.terrier.querying.LocalManager -- mahler { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2f54a33d] tags=[firstmatchscore]} sixth { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1018bde2] tags=[firstmatchscore]} symphoni { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@65b3f4a4] tags=[firstmatchscore]} concert { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@f2ff811] tags=[firstmatchscore]} 2025 { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@568ff82] tags=[firstmatchscore]}
# 17:42:24.667 [main] INFO org.terrier.matching.PostingListManager -- Query 16 with 5 terms has 5 posting lists
# 17:42:24.659 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.659 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.660 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.660 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.661 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.662 [main] INFO org.terrier.querying.LocalManager -- mahler { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2f54a33d] tags=[firstmatchscore]} sixth { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1018bde2] tags=[firstmatchscore]} symphoni { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@65b3f4a4] tags=[firstmatchscore]} concert { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@f2ff811] tags=[firstmatchscore]} 2025 { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@568ff82] tags=[firstmatchscore]}
# 17:42:24.667 [main] INFO org.terrier.matching.PostingListManager -- Query 16 with 5 terms has 5 posting lists
# 17:42:24.672 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.673 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.672 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.673 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.756 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 16 in 98ms - 1000 results retrieved
# 17:42:24.766 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 18 - climate change effects on agriculture
# 17:42:24.756 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 16 in 98ms - 1000 results retrieved
# 17:42:24.766 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 18 - climate change effects on agriculture
# 17:42:24.767 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.767 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.768 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.768 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.769 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.770 [main] INFO org.terrier.querying.LocalManager -- climat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@50caa560] tags=[firstmatchscore]} chang { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2a266d09] tags=[firstmatchscore]} effect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5ab9e72c] tags=[firstmatchscore]} agricultur { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@186f8716] tags=[firstmatchscore]}
# 17:42:24.774 [main] INFO org.terrier.matching.PostingListManager -- Query 18 with 4 terms has 4 posting lists
# 17:42:24.767 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.767 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.768 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.768 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.769 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.770 [main] INFO org.terrier.querying.LocalManager -- climat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@50caa560] tags=[firstmatchscore]} chang { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2a266d09] tags=[firstmatchscore]} effect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5ab9e72c] tags=[firstmatchscore]} agricultur { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@186f8716] tags=[firstmatchscore]}
# 17:42:24.774 [main] INFO org.terrier.matching.PostingListManager -- Query 18 with 4 terms has 4 posting lists
# 17:42:24.783 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.784 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.783 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.784 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.869 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 18 in 103ms - 1000 results retrieved
# 17:42:24.879 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 20 - history of urban rooftop gardening in european cities
# 17:42:24.869 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 18 in 103ms - 1000 results retrieved
# 17:42:24.879 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 20 - history of urban rooftop gardening in european cities
# 17:42:24.880 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.880 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.881 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.881 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.882 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.883 [main] INFO org.terrier.querying.LocalManager -- histori { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1d8bd0de] tags=[firstmatchscore]} urban { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@45ca843] tags=[firstmatchscore]} rooftop { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@11c9af63] tags=[firstmatchscore]} garden { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@757acd7b] tags=[firstmatchscore]} european { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@36b4fe2a] tags=[firstmatchscore]} citi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@574b560f] tags=[firstmatchscore]}
# 17:42:24.889 [main] INFO org.terrier.matching.PostingListManager -- Query 20 with 6 terms has 6 posting lists
# 17:42:24.880 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.880 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.881 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.881 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.882 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.883 [main] INFO org.terrier.querying.LocalManager -- histori { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1d8bd0de] tags=[firstmatchscore]} urban { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@45ca843] tags=[firstmatchscore]} rooftop { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@11c9af63] tags=[firstmatchscore]} garden { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@757acd7b] tags=[firstmatchscore]} european { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@36b4fe2a] tags=[firstmatchscore]} citi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@574b560f] tags=[firstmatchscore]}
# 17:42:24.889 [main] INFO org.terrier.matching.PostingListManager -- Query 20 with 6 terms has 6 posting lists
# 17:42:24.897 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.898 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.897 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.898 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.975 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 20 in 96ms - 1000 results retrieved
# 17:42:24.986 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 23 - excel sum cells
# 17:42:24.975 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 20 in 96ms - 1000 results retrieved
# 17:42:24.986 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 23 - excel sum cells
# 17:42:24.986 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.987 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.987 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.988 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.988 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.989 [main] INFO org.terrier.querying.LocalManager -- excel { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@ba54932] tags=[firstmatchscore]} sum { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@28975c28] tags=[firstmatchscore]} cell { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3943a2be] tags=[firstmatchscore]}
# 17:42:24.992 [main] INFO org.terrier.matching.PostingListManager -- Query 23 with 3 terms has 3 posting lists
# 17:42:24.995 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.996 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:24.986 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:24.987 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:24.987 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:24.988 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:24.988 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:24.989 [main] INFO org.terrier.querying.LocalManager -- excel { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@ba54932] tags=[firstmatchscore]} sum { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@28975c28] tags=[firstmatchscore]} cell { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3943a2be] tags=[firstmatchscore]}
# 17:42:24.992 [main] INFO org.terrier.matching.PostingListManager -- Query 23 with 3 terms has 3 posting lists
# 17:42:24.995 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:24.996 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.077 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 23 in 91ms - 1000 results retrieved
# 17:42:25.087 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 24 - iceland nature
# 17:42:25.077 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 23 in 91ms - 1000 results retrieved
# 17:42:25.087 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 24 - iceland nature
# 17:42:25.088 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.088 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.089 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.089 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.090 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.091 [main] INFO org.terrier.querying.LocalManager -- iceland { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@343570b7] tags=[firstmatchscore]} natur { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@157853da] tags=[firstmatchscore]}
# 17:42:25.094 [main] INFO org.terrier.matching.PostingListManager -- Query 24 with 2 terms has 2 posting lists
# 17:42:25.097 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.097 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.088 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.088 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.089 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.089 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.090 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.091 [main] INFO org.terrier.querying.LocalManager -- iceland { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@343570b7] tags=[firstmatchscore]} natur { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@157853da] tags=[firstmatchscore]}
# 17:42:25.094 [main] INFO org.terrier.matching.PostingListManager -- Query 24 with 2 terms has 2 posting lists
# 17:42:25.097 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.097 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.175 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 24 in 88ms - 1000 results retrieved
# 17:42:25.185 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 31 - decision trees
# 17:42:25.175 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 24 in 88ms - 1000 results retrieved
# 17:42:25.185 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 31 - decision trees
# 17:42:25.185 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.186 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.186 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.187 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.188 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.189 [main] INFO org.terrier.querying.LocalManager -- decis { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@71c3b41] tags=[firstmatchscore]} tree { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@236e3f4e] tags=[firstmatchscore]}
# 17:42:25.192 [main] INFO org.terrier.matching.PostingListManager -- Query 31 with 2 terms has 2 posting lists
# 17:42:25.185 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.186 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.186 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.187 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.188 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.189 [main] INFO org.terrier.querying.LocalManager -- decis { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@71c3b41] tags=[firstmatchscore]} tree { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@236e3f4e] tags=[firstmatchscore]}
# 17:42:25.192 [main] INFO org.terrier.matching.PostingListManager -- Query 31 with 2 terms has 2 posting lists
# 17:42:25.195 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.196 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.195 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.196 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.274 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 31 in 89ms - 1000 results retrieved
# 17:42:25.284 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 32 - hyperion dan simmons review
# 17:42:25.274 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 31 in 89ms - 1000 results retrieved
# 17:42:25.284 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 32 - hyperion dan simmons review
# 17:42:25.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.286 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.286 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.288 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.288 [main] INFO org.terrier.querying.LocalManager -- hyperion { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3cc1435c] tags=[firstmatchscore]} dan { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6bf0219d] tags=[firstmatchscore]} simmon { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@dd0c991] tags=[firstmatchscore]} review { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5f16132a] tags=[firstmatchscore]}
# 17:42:25.293 [main] INFO org.terrier.matching.PostingListManager -- Query 32 with 4 terms has 4 posting lists
# 17:42:25.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.285 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.286 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.286 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.288 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.288 [main] INFO org.terrier.querying.LocalManager -- hyperion { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3cc1435c] tags=[firstmatchscore]} dan { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6bf0219d] tags=[firstmatchscore]} simmon { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@dd0c991] tags=[firstmatchscore]} review { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5f16132a] tags=[firstmatchscore]}
# 17:42:25.293 [main] INFO org.terrier.matching.PostingListManager -- Query 32 with 4 terms has 4 posting lists
# 17:42:25.297 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.298 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.297 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.298 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.375 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 32 in 91ms - 1000 results retrieved
# 17:42:25.385 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 34 - early detection of fake news
# 17:42:25.386 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.375 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 32 in 91ms - 1000 results retrieved
# 17:42:25.385 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 34 - early detection of fake news
# 17:42:25.386 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.386 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.387 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.387 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.388 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.389 [main] INFO org.terrier.querying.LocalManager -- earli { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@69fb6037] tags=[firstmatchscore]} detect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@36d585c] tags=[firstmatchscore]} fake { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@87a85e1] tags=[firstmatchscore]} new { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@671a5887] tags=[firstmatchscore]}
# 17:42:25.393 [main] INFO org.terrier.matching.PostingListManager -- Query 34 with 4 terms has 4 posting lists
# 17:42:25.386 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.387 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.387 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.388 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.389 [main] INFO org.terrier.querying.LocalManager -- earli { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@69fb6037] tags=[firstmatchscore]} detect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@36d585c] tags=[firstmatchscore]} fake { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@87a85e1] tags=[firstmatchscore]} new { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@671a5887] tags=[firstmatchscore]}
# 17:42:25.393 [main] INFO org.terrier.matching.PostingListManager -- Query 34 with 4 terms has 4 posting lists
# 17:42:25.404 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.404 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.404 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.404 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.512 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 34 in 127ms - 1000 results retrieved
# 17:42:25.527 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 39 - renewable energy storage solutions
# 17:42:25.512 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 34 in 127ms - 1000 results retrieved
# 17:42:25.527 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 39 - renewable energy storage solutions
# 17:42:25.528 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.528 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.529 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.530 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.531 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.531 [main] INFO org.terrier.querying.LocalManager -- renew { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5552768b] tags=[firstmatchscore]} energi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3c947bc5] tags=[firstmatchscore]} storag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@609db43b] tags=[firstmatchscore]} solut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@55f616cf] tags=[firstmatchscore]}
# 17:42:25.536 [main] INFO org.terrier.matching.PostingListManager -- Query 39 with 4 terms has 4 posting lists
# 17:42:25.528 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.528 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.529 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.530 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.531 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.531 [main] INFO org.terrier.querying.LocalManager -- renew { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5552768b] tags=[firstmatchscore]} energi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3c947bc5] tags=[firstmatchscore]} storag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@609db43b] tags=[firstmatchscore]} solut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@55f616cf] tags=[firstmatchscore]}
# 17:42:25.536 [main] INFO org.terrier.matching.PostingListManager -- Query 39 with 4 terms has 4 posting lists
# 17:42:25.542 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.543 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.542 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.543 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.617 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 39 in 90ms - 1000 results retrieved
# 17:42:25.617 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 39 in 90ms - 1000 results retrieved
# 17:42:25.627 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 42 - automatic speech recognition
# 17:42:25.627 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.628 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.628 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.629 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.630 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:25.630 [main] INFO org.terrier.querying.LocalManager -- automat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1356d4d4] tags=[firstmatchscore]} speech { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@c03cf28] tags=[firstmatchscore]} recognit { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1329eff] tags=[firstmatchscore]}
# 17:42:25.633 [main] INFO org.terrier.matching.PostingListManager -- Query 42 with 3 terms has 3 posting lists
# 17:42:25.636 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:25.636 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:25.627 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 42 - automatic speech recognition
# 17:42:25.627 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:25.628 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:25.628 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:25.629 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:25.630 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# ...
# 17:42:28.668 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.669 [main] INFO org.terrier.querying.LocalManager -- averag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5ace1ed4] tags=[firstmatchscore]} data { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1613674b] tags=[firstmatchscore]} scientist { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@27ff5d15] tags=[firstmatchscore]} salari { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4e096385] tags=[firstmatchscore]}
# 17:42:28.670 [main] INFO org.terrier.matching.PostingListManager -- Query 64 with 4 terms has 4 posting lists
# 17:42:28.665 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 64 - average data scientist salary
# 17:42:28.665 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.666 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.667 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.667 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.668 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.669 [main] INFO org.terrier.querying.LocalManager -- averag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5ace1ed4] tags=[firstmatchscore]} data { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1613674b] tags=[firstmatchscore]} scientist { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@27ff5d15] tags=[firstmatchscore]} salari { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4e096385] tags=[firstmatchscore]}
# 17:42:28.670 [main] INFO org.terrier.matching.PostingListManager -- Query 64 with 4 terms has 4 posting lists
# 17:42:28.688 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.689 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.688 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.689 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.708 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 64 in 43ms - 1000 results retrieved
# 117:42:28.708 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 64 in 43ms - 1000 results retrieved
# 17:42:28.719 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 68 - drinking water purification methods
# 17:42:28.720 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.721 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.721 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.722 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.723 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.723 [main] INFO org.terrier.querying.LocalManager -- drink { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@649bec2e] tags=[firstmatchscore]} water { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@693fe6c9] tags=[firstmatchscore]} purif { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@34f5090e] tags=[firstmatchscore]} method { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@31e5415e] tags=[firstmatchscore]}
# 17:42:28.724 [main] INFO org.terrier.matching.PostingListManager -- Query 68 with 4 terms has 4 posting lists
# 7:42:28.719 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 68 - drinking water purification methods
# 17:42:28.720 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.721 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.721 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.722 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.723 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.723 [main] INFO org.terrier.querying.LocalManager -- drink { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@649bec2e] tags=[firstmatchscore]} water { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@693fe6c9] tags=[firstmatchscore]} purif { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@34f5090e] tags=[firstmatchscore]} method { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@31e5415e] tags=[firstmatchscore]}
# 17:42:28.724 [main] INFO org.terrier.matching.PostingListManager -- Query 68 with 4 terms has 4 posting lists
# 17:42:28.740 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.748 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.740 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.748 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.809 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 68 in 90ms - 1000 results retrieved
# 17:42:28.819 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 69 - the rings of power
# 17:42:28.809 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 68 in 90ms - 1000 results retrieved
# 17:42:28.819 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 69 - the rings of power
# 17:42:28.820 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.820 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.821 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.822 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.823 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.823 [main] INFO org.terrier.querying.LocalManager -- ring { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@a2431d0] tags=[firstmatchscore]} power { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1cbb87f3] tags=[firstmatchscore]}
# 17:42:28.824 [main] INFO org.terrier.matching.PostingListManager -- Query 69 with 2 terms has 2 posting lists
# 17:42:28.820 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.820 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.821 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.822 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.823 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.823 [main] INFO org.terrier.querying.LocalManager -- ring { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@a2431d0] tags=[firstmatchscore]} power { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1cbb87f3] tags=[firstmatchscore]}
# 17:42:28.824 [main] INFO org.terrier.matching.PostingListManager -- Query 69 with 2 terms has 2 posting lists
# 17:42:28.834 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.834 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.834 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.834 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.866 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 69 in 47ms - 1000 results retrieved
# 17:42:28.876 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 74 - homeassistant setup
# 17:42:28.866 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 69 in 47ms - 1000 results retrieved
# 17:42:28.876 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 74 - homeassistant setup
# 17:42:28.877 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.877 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.878 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.879 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.879 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.880 [main] INFO org.terrier.querying.LocalManager -- homeassist { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1a4013] tags=[firstmatchscore]} setup { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1b6e1eff] tags=[firstmatchscore]}
# 17:42:28.881 [main] INFO org.terrier.matching.PostingListManager -- Query 74 with 2 terms has 2 posting lists
# 17:42:28.883 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.883 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.877 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 17:42:28.877 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 17:42:28.878 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 17:42:28.879 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 17:42:28.879 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 17:42:28.880 [main] INFO org.terrier.querying.LocalManager -- homeassist { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1a4013] tags=[firstmatchscore]} setup { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1b6e1eff] tags=[firstmatchscore]}
# 17:42:28.881 [main] INFO org.terrier.matching.PostingListManager -- Query 74 with 2 terms has 2 posting lists
# 17:42:28.883 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 17:42:28.883 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 17:42:28.899 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 74 in 23ms - 1000 results retrieved
# 17:42:28.899 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 74 in 23ms - 1000 results retrieved
# 17:42:29.160 [main] INFO org.terrier.realtime.memory.MemoryIndex -- ***REALTIME*** MemoryIndex (NEW)
# 17:42:29.160 [main] INFO org.terrier.realtime.memory.MemoryIndex -- ***REALTIME*** MemoryIndex (NEW)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 ltr_pipeline = pipeline >> pt.ltr.apply_learned_model(xgb_ranker, form="ltr")
# ----> 3 ltr_pipeline.fit(train_topics, train_qrels, valid_topics, valid_qrels)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/_ops.py:385, in Compose.fit(self, topics_or_res_tr, qrels_tr, topics_or_res_va, qrels_va)
#     383     m.fit(topics_or_res_tr, qrels_tr, topics_or_res_va, qrels_va)
#     384 else:
# --> 385     topics_or_res_tr = m.transform(topics_or_res_tr)
#     386     # validation is optional for some learners
#     387     if topics_or_res_va is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/_ops.py:232, in FeatureUnion.transform(self, inputRes)
#     228 all_results = []
#     230 for i, m in enumerate(self._transformers):
#     231     # IMPORTANT this .copy() is important, in case an operand transformer changes inputRes
# --> 232     results = m.transform(inputRes.copy())
#     233     if len(results) == 0 and num_results != 0:
#     234         raise ValueError("Got no results from %s, expected %d" % (repr(m), num_results) )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/utils.py:139, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     136 @wraps(fn)
#     137 def _wrapper(*args, **kwargs):
#     138     decorator(fn)
# --> 139     return fn(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/terrier/retriever.py:516, in TextIndexProcessor.transform(self, topics_and_res)
#     514 from pyterrier.terrier.index import IndexingType, _IterDictIndexer_nofifo
#     515 documents = topics_and_res[["docno", self.body_attr]].drop_duplicates(subset="docno").rename(columns={self.body_attr:'text'})
# --> 516 indexref = _IterDictIndexer_nofifo(None, type=IndexingType.MEMORY, verbose=self.verbose).index(documents.to_dict(orient='records'))
#     517 docno2docid = { docno:id for id, docno in enumerate(documents["docno"]) }
#     518 index_docs = IndexFactory.of(indexref)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/utils.py:139, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     136 @wraps(fn)
#     137 def _wrapper(*args, **kwargs):
#     138     decorator(fn)
# --> 139     return fn(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/terrier/index.py:680, in _IterDictIndexer_nofifo.index(self, it, fields)
#     675     iter_docs = None
#     677 else:
#     678
#     679     # we need to prevent collectionIterator from being GCd
# --> 680     collectionIterator = FlatJSONDocumentIterator(self._filter_iterable(it))
#     681     javaDocCollection = pt.terrier.J.CollectionFromDocumentIterator(collectionIterator)
#     682     indexer.index(javaDocCollection)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/terrier/index.py:611, in _BaseIterDictIndexer._filter_iterable(self, it)
#     609 first_docs, it = more_itertools.spy(it) # peek at the first document and validate it
#     610 if len(first_docs) > 0: # handle empty input
# --> 611     self._validate_doc_dict(first_docs[0])
#     613 # important: return an iterator (i.e. using a generator expression) here, rather than make this
#     614 # function a generator, to be sure that the validation above happens when  _filter_iterable is
#     615 # called, rather than on the first invocation of next()
#     616 return ({f: doc[f] for f in all_cols} for doc in it)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/terrier/index.py:636, in _BaseIterDictIndexer._validate_doc_dict(self, obj)
#     632 msg = f"Indexing meta key {k} length requested {self.meta[k]} but exceeded in first document (actual length {len(obj[k])}). " + \
#     633       f"Increase the length in the meta dict for the indexer, e.g., pt.IterDictIndexer(..., meta={ {k: len(obj[k])} })."
#     634 if k == 'docno':
#     635     # docnos that are truncated will cause major issues; raise an error
# --> 636     raise ValueError(msg)
#     637 else:
#     638     # Other fields may not matter as much; just show a warning
#     639     warn(msg)
#
# ValueError: Indexing meta key docno length requested 20 but exceeded in first document (actual length 64). Increase the length in the meta dict for the indexer, e.g., pt.IterDictIndexer(..., meta={'docno': 64}).

# %%
results = ltr_pipeline.transform(valid_topics)

#results.to_csv("ltr_results_nn.csv", index=False)
print(results.head(10))
# Out:
# 21:28:05.450 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 651 - U S  ethnic population
# 21:28:05.452 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.455 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.457 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.459 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.463 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.465 [main] INFO org.terrier.querying.LocalManager -- ethnic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4b29d1d2] tags=[firstmatchscore]} popul { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7f485fda] tags=[firstmatchscore]}
# 21:28:05.469 [main] INFO org.terrier.matching.PostingListManager -- Query 651 with 2 terms has 2 posting lists
# 21:28:05.476 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.479 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:05.514 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 651 in 64ms - 1000 results retrieved
# 21:28:05.536 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 652 - OIC Balkans 1990s
# 21:28:05.538 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.540 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.542 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.544 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.545 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.547 [main] INFO org.terrier.querying.LocalManager -- oic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@28261e8e] tags=[firstmatchscore]} balkan { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@d737b89] tags=[firstmatchscore]} 1990 { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@8519cb4] tags=[firstmatchscore]}
# 21:28:05.551 [main] INFO org.terrier.matching.PostingListManager -- Query 652 with 3 terms has 3 posting lists
# 21:28:05.562 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.565 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:05.593 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 652 in 57ms - 1000 results retrieved
# 21:28:05.617 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 653 - ETA Basque terrorism
# 21:28:05.619 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.621 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.622 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.623 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.625 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.626 [main] INFO org.terrier.querying.LocalManager -- eta { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@35dab4eb] tags=[firstmatchscore]} basqu { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2d901eb0] tags=[firstmatchscore]} terror { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3ba987b8] tags=[firstmatchscore]}
# 21:28:05.632 [main] INFO org.terrier.matching.PostingListManager -- Query 653 with 3 terms has 3 posting lists
# 21:28:05.635 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.636 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:05.665 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 653 in 48ms - 1000 results retrieved
# 21:28:05.688 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 654 - same sex schools
# 21:28:05.690 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.691 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.693 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.696 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.699 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.701 [main] INFO org.terrier.querying.LocalManager -- sex { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3f191845] tags=[firstmatchscore]} school { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5f049ea1] tags=[firstmatchscore]}
# 21:28:05.703 [main] INFO org.terrier.matching.PostingListManager -- Query 654 with 2 terms has 2 posting lists
# 21:28:05.710 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.713 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:05.744 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 654 in 56ms - 1000 results retrieved
# 21:28:05.768 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 655 - ADD diagnosis treatment
# 21:28:05.770 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.773 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.774 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.776 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.778 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.780 [main] INFO org.terrier.querying.LocalManager -- add { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@72cc7e6f] tags=[firstmatchscore]} diagnosi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5afa3c9] tags=[firstmatchscore]} treatment { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@72035809] tags=[firstmatchscore]}
# 21:28:05.783 [main] INFO org.terrier.matching.PostingListManager -- Query 655 with 3 terms has 3 posting lists
# 21:28:05.790 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.792 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:05.824 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 655 in 56ms - 1000 results retrieved
# 21:28:05.849 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 656 - lead poisoning children
# 21:28:05.851 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.852 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.853 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.855 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.856 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.858 [main] INFO org.terrier.querying.LocalManager -- lead { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@909217e] tags=[firstmatchscore]} poison { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@18271936] tags=[firstmatchscore]} children { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@606e4010] tags=[firstmatchscore]}
# 21:28:05.862 [main] INFO org.terrier.matching.PostingListManager -- Query 656 with 3 terms has 3 posting lists
# 21:28:05.876 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.879 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:05.914 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 656 in 65ms - 1000 results retrieved
# 21:28:05.940 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 657 - school prayer banned
# 21:28:05.941 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:05.946 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:05.949 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:05.950 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:05.951 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:05.953 [main] INFO org.terrier.querying.LocalManager -- school { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@8458f04] tags=[firstmatchscore]} prayer { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@48075da3] tags=[firstmatchscore]} ban { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@68c9133c] tags=[firstmatchscore]}
# 21:28:05.957 [main] INFO org.terrier.matching.PostingListManager -- Query 657 with 3 terms has 3 posting lists
# 21:28:05.965 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:05.969 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.037 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 657 in 97ms - 1000 results retrieved
# 21:28:06.070 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 658 - teenage pregnancy
# 21:28:06.071 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.073 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.074 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.075 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.077 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.080 [main] INFO org.terrier.querying.LocalManager -- teenag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7a35b0f5] tags=[firstmatchscore]} pregnanc { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5e2c3d18] tags=[firstmatchscore]}
# 21:28:06.084 [main] INFO org.terrier.matching.PostingListManager -- Query 658 with 2 terms has 2 posting lists
# 21:28:06.086 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.088 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.118 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 658 in 48ms - 1000 results retrieved
# 21:28:06.139 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 659 - cruise health safety
# 21:28:06.140 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.143 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.146 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.148 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.151 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.153 [main] INFO org.terrier.querying.LocalManager -- cruis { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2cb4893b] tags=[firstmatchscore]} health { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@cc43f62] tags=[firstmatchscore]} safeti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5b218417] tags=[firstmatchscore]}
# 21:28:06.158 [main] INFO org.terrier.matching.PostingListManager -- Query 659 with 3 terms has 3 posting lists
# 21:28:06.166 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.168 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.203 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 659 in 64ms - 1000 results retrieved
# 21:28:06.224 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 660 - whale watching California
# 21:28:06.225 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.228 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.230 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.233 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.233 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.236 [main] INFO org.terrier.querying.LocalManager -- whale { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@645aa696] tags=[firstmatchscore]} watch { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6caf0677] tags=[firstmatchscore]} california { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@413d1baf] tags=[firstmatchscore]}
# 21:28:06.240 [main] INFO org.terrier.matching.PostingListManager -- Query 660 with 3 terms has 3 posting lists
# 21:28:06.249 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.251 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.285 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 660 in 61ms - 1000 results retrieved
# 21:28:06.312 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 661 - melanoma treatment causes
# 21:28:06.315 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.316 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.318 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.319 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.321 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.322 [main] INFO org.terrier.querying.LocalManager -- melanoma { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@16eb3ea3] tags=[firstmatchscore]} treatment { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@273444fe] tags=[firstmatchscore]} caus { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@33bc72d1] tags=[firstmatchscore]}
# 21:28:06.326 [main] INFO org.terrier.matching.PostingListManager -- Query 661 with 3 terms has 3 posting lists
# 21:28:06.336 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.338 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.369 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 661 in 57ms - 1000 results retrieved
# 21:28:06.390 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 662 - telemarketer protection
# 21:28:06.391 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.396 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.399 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.401 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.403 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.404 [main] INFO org.terrier.querying.LocalManager -- telemarket { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1a75e76a] tags=[firstmatchscore]} protect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5524cca1] tags=[firstmatchscore]}
# 21:28:06.406 [main] INFO org.terrier.matching.PostingListManager -- Query 662 with 2 terms has 2 posting lists
# 21:28:06.413 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.414 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.450 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 662 in 60ms - 1000 results retrieved
# 21:28:06.470 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 663 - Agent Orange exposure
# 21:28:06.472 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.474 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.476 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.480 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.483 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.485 [main] INFO org.terrier.querying.LocalManager -- agent { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5032714f] tags=[firstmatchscore]} orang { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@48bb62] tags=[firstmatchscore]} exposur { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@353352b6] tags=[firstmatchscore]}
# 21:28:06.489 [main] INFO org.terrier.matching.PostingListManager -- Query 663 with 3 terms has 3 posting lists
# 21:28:06.498 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.499 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.532 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 663 in 62ms - 1000 results retrieved
# 21:28:06.554 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 664 - American Indian Museum
# 21:28:06.556 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.558 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.559 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.561 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.564 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.566 [main] INFO org.terrier.querying.LocalManager -- american { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4681c175] tags=[firstmatchscore]} indian { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@57a78e3] tags=[firstmatchscore]} museum { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@402c4085] tags=[firstmatchscore]}
# 21:28:06.570 [main] INFO org.terrier.matching.PostingListManager -- Query 664 with 3 terms has 3 posting lists
# 21:28:06.579 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.582 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.618 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 664 in 64ms - 1000 results retrieved
# 21:28:06.641 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 665 - poverty Africa sub Sahara
# 21:28:06.644 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.646 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.649 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.651 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.651 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.654 [main] INFO org.terrier.querying.LocalManager -- poverti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6fa51cd4] tags=[firstmatchscore]} africa { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2767e23c] tags=[firstmatchscore]} sub { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@710c2b53] tags=[firstmatchscore]} sahara { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5386659f] tags=[firstmatchscore]}
# 21:28:06.656 [main] INFO org.terrier.matching.PostingListManager -- Query 665 with 4 terms has 4 posting lists
# 21:28:06.662 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.666 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.697 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 665 in 56ms - 1000 results retrieved
# 21:28:06.720 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 666 - Thatcher resignation impact
# 21:28:06.721 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.723 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.724 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.726 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.729 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.731 [main] INFO org.terrier.querying.LocalManager -- thatcher { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@14028087] tags=[firstmatchscore]} resign { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@cecf639] tags=[firstmatchscore]} impact { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1caa0244] tags=[firstmatchscore]}
# 21:28:06.735 [main] INFO org.terrier.matching.PostingListManager -- Query 666 with 3 terms has 3 posting lists
# 21:28:06.741 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.746 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.775 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 666 in 55ms - 1000 results retrieved
# 21:28:06.802 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 667 - unmarried partner households
# 21:28:06.802 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.804 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.806 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.807 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.807 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.809 [main] INFO org.terrier.querying.LocalManager -- unmarri { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7ce026d3] tags=[firstmatchscore]} partner { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7ce69770] tags=[firstmatchscore]} household { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1750fbeb] tags=[firstmatchscore]}
# 21:28:06.815 [main] INFO org.terrier.matching.PostingListManager -- Query 667 with 3 terms has 3 posting lists
# 21:28:06.821 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.823 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.855 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 667 in 53ms - 1000 results retrieved
# 21:28:06.875 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 668 - poverty  disease
# 21:28:06.878 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.882 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.882 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.885 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.887 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.887 [main] INFO org.terrier.querying.LocalManager -- poverti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5b247367] tags=[firstmatchscore]} diseas { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@268f106e] tags=[firstmatchscore]}
# 21:28:06.890 [main] INFO org.terrier.matching.PostingListManager -- Query 668 with 2 terms has 2 posting lists
# 21:28:06.895 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.897 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:06.926 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 668 in 51ms - 1000 results retrieved
# 21:28:06.950 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 669 - Islamic Revolution
# 21:28:06.952 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:06.955 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:06.958 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:06.962 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:06.965 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:06.968 [main] INFO org.terrier.querying.LocalManager -- islam { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6e9a5ed8] tags=[firstmatchscore]} revolut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7e057f43] tags=[firstmatchscore]}
# 21:28:06.972 [main] INFO org.terrier.matching.PostingListManager -- Query 669 with 2 terms has 2 posting lists
# 21:28:06.976 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:06.981 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.018 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 669 in 68ms - 1000 results retrieved
# 21:28:07.049 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 670 - U S  elections apathy
# 21:28:07.052 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.055 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.057 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.058 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.060 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.064 [main] INFO org.terrier.querying.LocalManager -- elect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6c284af] tags=[firstmatchscore]} apathi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5890e879] tags=[firstmatchscore]}
# 21:28:07.069 [main] INFO org.terrier.matching.PostingListManager -- Query 670 with 2 terms has 2 posting lists
# 21:28:07.076 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.082 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.156 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 670 in 107ms - 1000 results retrieved
# 21:28:07.209 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 671 - Salvation Army benefits
# 21:28:07.214 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.215 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.217 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.218 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.220 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.221 [main] INFO org.terrier.querying.LocalManager -- salvat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6440112d] tags=[firstmatchscore]} armi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@31ea9581] tags=[firstmatchscore]} benefit { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@231f98ef] tags=[firstmatchscore]}
# 21:28:07.224 [main] INFO org.terrier.matching.PostingListManager -- Query 671 with 3 terms has 3 posting lists
# 21:28:07.235 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.237 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.267 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 671 in 58ms - 1000 results retrieved
# 21:28:07.289 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 672 - NRA membership profile
# 21:28:07.292 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.294 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.298 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.300 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.302 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.304 [main] INFO org.terrier.querying.LocalManager -- nra { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7c137fd5] tags=[firstmatchscore]} membership { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@183ec003] tags=[firstmatchscore]} profil { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7d9d0818] tags=[firstmatchscore]}
# 21:28:07.307 [main] INFO org.terrier.matching.PostingListManager -- Query 672 with 3 terms has 3 posting lists
# 21:28:07.313 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.315 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.349 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 672 in 60ms - 1000 results retrieved
# 21:28:07.372 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 673 - Soviet withdrawal Afghanistan
# 21:28:07.374 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.375 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.380 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.382 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.384 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.385 [main] INFO org.terrier.querying.LocalManager -- soviet { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@221a3fa4] tags=[firstmatchscore]} withdraw { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@451001e5] tags=[firstmatchscore]} afghanistan { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2b40ff9c] tags=[firstmatchscore]}
# 21:28:07.389 [main] INFO org.terrier.matching.PostingListManager -- Query 673 with 3 terms has 3 posting lists
# 21:28:07.398 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.400 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.432 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 673 in 60ms - 1000 results retrieved
# 21:28:07.456 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 674 - Greenpeace prosecuted
# 21:28:07.458 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.459 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.464 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.465 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.467 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.468 [main] INFO org.terrier.querying.LocalManager -- greenpeac { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3e08ff24] tags=[firstmatchscore]} prosecut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4d1c005e] tags=[firstmatchscore]}
# 21:28:07.471 [main] INFO org.terrier.matching.PostingListManager -- Query 674 with 2 terms has 2 posting lists
# 21:28:07.475 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.477 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.511 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 674 in 55ms - 1000 results retrieved
# 21:28:07.536 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 675 - Olympics training swimming
# 21:28:07.536 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.539 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.540 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.541 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.541 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.545 [main] INFO org.terrier.querying.LocalManager -- olymp { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@8462f31] tags=[firstmatchscore]} train { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@24569dba] tags=[firstmatchscore]} swim { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5ddeb7cb] tags=[firstmatchscore]}
# 21:28:07.550 [main] INFO org.terrier.matching.PostingListManager -- Query 675 with 3 terms has 3 posting lists
# 21:28:07.556 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.558 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.589 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 675 in 53ms - 1000 results retrieved
# 21:28:07.610 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 676 - poppy cultivation
# 21:28:07.614 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.616 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.618 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.619 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.621 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.622 [main] INFO org.terrier.querying.LocalManager -- poppi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@70ed52de] tags=[firstmatchscore]} cultiv { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@496bc455] tags=[firstmatchscore]}
# 21:28:07.624 [main] INFO org.terrier.matching.PostingListManager -- Query 676 with 2 terms has 2 posting lists
# 21:28:07.626 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.629 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.660 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 676 in 50ms - 1000 results retrieved
# 21:28:07.685 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 677 - Leaning Tower of Pisa
# 21:28:07.686 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.688 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.689 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.690 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.691 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.693 [main] INFO org.terrier.querying.LocalManager -- lean { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@59402b8f] tags=[firstmatchscore]} tower { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7188af83] tags=[firstmatchscore]} pisa { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6be968ce] tags=[firstmatchscore]}
# 21:28:07.697 [main] INFO org.terrier.matching.PostingListManager -- Query 677 with 3 terms has 3 posting lists
# 21:28:07.701 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.703 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.733 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 677 in 48ms - 1000 results retrieved
# 21:28:07.759 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 678 - joint custody impact
# 21:28:07.762 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.766 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.768 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.769 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.770 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.772 [main] INFO org.terrier.querying.LocalManager -- joint { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7c37508a] tags=[firstmatchscore]} custodi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@247310d0] tags=[firstmatchscore]} impact { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1033576a] tags=[firstmatchscore]}
# 21:28:07.775 [main] INFO org.terrier.matching.PostingListManager -- Query 678 with 3 terms has 3 posting lists
# 21:28:07.785 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.786 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.817 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 678 in 58ms - 1000 results retrieved
# 21:28:07.840 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 679 - opening adoption records
# 21:28:07.840 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.842 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.846 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.849 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.851 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.853 [main] INFO org.terrier.querying.LocalManager -- open { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@303cf2ba] tags=[firstmatchscore]} adopt { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@76494737] tags=[firstmatchscore]} record { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4a003cbe] tags=[firstmatchscore]}
# 21:28:07.856 [main] INFO org.terrier.matching.PostingListManager -- Query 679 with 3 terms has 3 posting lists
# 21:28:07.876 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.880 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:07.923 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 679 in 83ms - 1000 results retrieved
# 21:28:07.974 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 680 - immigrants Spanish school
# 21:28:07.976 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:07.979 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:07.981 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:07.982 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:07.983 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:07.985 [main] INFO org.terrier.querying.LocalManager -- immigr { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4082ba93] tags=[firstmatchscore]} spanish { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@17fc391b] tags=[firstmatchscore]} school { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2b30a42c] tags=[firstmatchscore]}
# 21:28:07.988 [main] INFO org.terrier.matching.PostingListManager -- Query 680 with 3 terms has 3 posting lists
# 21:28:07.996 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:07.999 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:08.031 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 680 in 57ms - 1000 results retrieved
# 21:28:08.054 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 681 - wind power location
# 21:28:08.056 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:08.057 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:08.058 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:08.062 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:08.066 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:08.067 [main] INFO org.terrier.querying.LocalManager -- wind { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@609e8838] tags=[firstmatchscore]} power { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@359df09a] tags=[firstmatchscore]} locat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@43df23d3] tags=[firstmatchscore]}
# 21:28:08.071 [main] INFO org.terrier.matching.PostingListManager -- Query 681 with 3 terms has 3 posting lists
# 21:28:08.085 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:08.087 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:08.130 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 681 in 76ms - 1000 results retrieved
# 21:28:08.160 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 682 - adult immigrants English
# 21:28:08.164 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:08.167 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:08.169 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:08.170 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:08.173 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:08.174 [main] INFO org.terrier.querying.LocalManager -- adult { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6d60fe40] tags=[firstmatchscore]} immigr { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@792b749c] tags=[firstmatchscore]} english { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@23e84203] tags=[firstmatchscore]}
# 21:28:08.183 [main] INFO org.terrier.matching.PostingListManager -- Query 682 with 3 terms has 3 posting lists
# 21:28:08.197 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:08.202 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:08.239 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 682 in 79ms - 1000 results retrieved
# 21:28:08.269 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 683 - Czechoslovakia breakup
# 21:28:08.271 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:08.274 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:08.276 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:08.280 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:08.282 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:08.284 [main] INFO org.terrier.querying.LocalManager -- czechoslovakia { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@19932c16] tags=[firstmatchscore]} breakup { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@73eb439a] tags=[firstmatchscore]}
# 21:28:08.288 [main] INFO org.terrier.matching.PostingListManager -- Query 683 with 2 terms has 2 posting lists
# 21:28:08.293 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:08.299 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:08.337 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 683 in 68ms - 1000 results retrieved
# 21:28:08.357 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 684 - part time benefits
# ...
# 21:28:13.879 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:13.882 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:13.882 [main] INFO org.terrier.querying.LocalManager -- prostat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@6a4f1a55] tags=[firstmatchscore]} cancer { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7dfd3c81] tags=[firstmatchscore]} detect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@2584b82d] tags=[firstmatchscore]} treatment { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7bbc8656] tags=[firstmatchscore]}
# 21:28:13.888 [main] INFO org.terrier.matching.PostingListManager -- Query 692 with 4 terms has 4 posting lists
# 21:28:13.896 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:13.898 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:13.927 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 692 in 52ms - 1000 results retrieved
# 21:28:13.949 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 693 - newspapers electronic media
# 21:28:13.951 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:13.953 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:13.956 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:13.957 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:13.959 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:13.960 [main] INFO org.terrier.querying.LocalManager -- newspap { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@6933b6c6] tags=[firstmatchscore]} electron { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7d3e8655] tags=[firstmatchscore]} media { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7dfb0c0f] tags=[firstmatchscore]}
# 21:28:13.963 [main] INFO org.terrier.matching.PostingListManager -- Query 693 with 3 terms has 3 posting lists
# 21:28:13.974 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:13.976 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.007 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 693 in 58ms - 1000 results retrieved
# 21:28:14.027 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 694 - compost pile
# 21:28:14.028 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.030 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.032 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.034 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.035 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.037 [main] INFO org.terrier.querying.LocalManager -- compost { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@626abbd0] tags=[firstmatchscore]} pile { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@169bb4dd] tags=[firstmatchscore]}
# 21:28:14.041 [main] INFO org.terrier.matching.PostingListManager -- Query 694 with 2 terms has 2 posting lists
# 21:28:14.044 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.045 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.075 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 694 in 48ms - 1000 results retrieved
# 21:28:14.120 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 695 - white collar crime sentence
# 21:28:14.150 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.158 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.160 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.162 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.163 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.165 [main] INFO org.terrier.querying.LocalManager -- white { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1f9e9475] tags=[firstmatchscore]} collar { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@3aa078fd] tags=[firstmatchscore]} crime { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@d23e042] tags=[firstmatchscore]} sentenc { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@46d59067] tags=[firstmatchscore]}
# 21:28:14.180 [main] INFO org.terrier.matching.PostingListManager -- Query 695 with 4 terms has 4 posting lists
# 21:28:14.194 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.196 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.259 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 695 in 139ms - 1000 results retrieved
# 21:28:14.284 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 696 - safety plastic surgery
# 21:28:14.287 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.289 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.291 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.293 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.295 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.296 [main] INFO org.terrier.querying.LocalManager -- safeti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@2d0399f4] tags=[firstmatchscore]} plastic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@14dd7b39] tags=[firstmatchscore]} surgeri { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@66ea810] tags=[firstmatchscore]}
# 21:28:14.299 [main] INFO org.terrier.matching.PostingListManager -- Query 696 with 3 terms has 3 posting lists
# 21:28:14.311 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.313 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.349 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 696 in 65ms - 1000 results retrieved
# 21:28:14.376 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 697 - air traffic controller
# 21:28:14.378 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.379 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.380 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.382 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.383 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.386 [main] INFO org.terrier.querying.LocalManager -- air { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@6cd24612] tags=[firstmatchscore]} traffic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5dafbe45] tags=[firstmatchscore]} control { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@2254127a] tags=[firstmatchscore]}
# 21:28:14.391 [main] INFO org.terrier.matching.PostingListManager -- Query 697 with 3 terms has 3 posting lists
# 21:28:14.414 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.417 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.456 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 697 in 80ms - 1000 results retrieved
# 21:28:14.530 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 698 - literacy rates Africa
# 21:28:14.533 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.541 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.543 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.545 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.547 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.549 [main] INFO org.terrier.querying.LocalManager -- literaci { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@51891008] tags=[firstmatchscore]} rate { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@2f953efd] tags=[firstmatchscore]} africa { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@f68f0dc] tags=[firstmatchscore]}
# 21:28:14.565 [main] INFO org.terrier.matching.PostingListManager -- Query 698 with 3 terms has 3 posting lists
# 21:28:14.589 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.591 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.623 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 698 in 93ms - 1000 results retrieved
# 21:28:14.645 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 699 - term limits
# 21:28:14.647 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.647 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.650 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.652 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.656 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.657 [main] INFO org.terrier.querying.LocalManager -- term { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@d2de489] tags=[firstmatchscore]} limit { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@14bdbc74] tags=[firstmatchscore]}
# 21:28:14.660 [main] INFO org.terrier.matching.PostingListManager -- Query 699 with 2 terms has 2 posting lists
# 21:28:14.683 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.689 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.731 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 699 in 86ms - 1000 results retrieved
# 21:28:14.761 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 700 - gasoline tax U S
# 21:28:14.763 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:14.765 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:14.767 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:14.769 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:14.774 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:14.776 [main] INFO org.terrier.querying.LocalManager -- gasolin { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@12591ac8] tags=[firstmatchscore]} tax { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5a7fe64f] tags=[firstmatchscore]}
# 21:28:14.779 [main] INFO org.terrier.matching.PostingListManager -- Query 700 with 2 terms has 2 posting lists
# 21:28:14.793 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:14.795 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:14.878 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 700 in 117ms - 1000 results retrieved
#    qid  docid        docno                   query  \
# 0  651  15315  FBIS3-15316  U S  ethnic population
# 1  651  16227  FBIS3-16228  U S  ethnic population
# 2  651  17041  FBIS3-17042  U S  ethnic population
# 3  651  17054  FBIS3-17055  U S  ethnic population
# 4  651  17816  FBIS3-17817  U S  ethnic population
# 5  651  24360  FBIS3-24361  U S  ethnic population
# 6  651  26864  FBIS3-26865  U S  ethnic population
# 7  651  30703  FBIS3-30704  U S  ethnic population
# 8  651  35591  FBIS3-35592  U S  ethnic population
# 9  651  36509  FBIS3-36510  U S  ethnic population
#
#                                          description  \
# 0  How is the ethnic make-up of the U.S. populati...
# 1  How is the ethnic make-up of the U.S. populati...
# 2  How is the ethnic make-up of the U.S. populati...
# 3  How is the ethnic make-up of the U.S. populati...
# 4  How is the ethnic make-up of the U.S. populati...
# 5  How is the ethnic make-up of the U.S. populati...
# 6  How is the ethnic make-up of the U.S. populati...
# 7  How is the ethnic make-up of the U.S. populati...
# 8  How is the ethnic make-up of the U.S. populati...
# 9  How is the ethnic make-up of the U.S. populati...
#
#                                            narrative  \
# 0  Documents must indicate a shift in the ethnic ...
# 1  Documents must indicate a shift in the ethnic ...
# 2  Documents must indicate a shift in the ethnic ...
# 3  Documents must indicate a shift in the ethnic ...
# 4  Documents must indicate a shift in the ethnic ...
# 5  Documents must indicate a shift in the ethnic ...
# 6  Documents must indicate a shift in the ethnic ...
# 7  Documents must indicate a shift in the ethnic ...
# 8  Documents must indicate a shift in the ethnic ...
# 9  Documents must indicate a shift in the ethnic ...
#
#                                                 body  \
# 0  Language: Russian\nArticle Type:BFN\n[Svetlana...
# 1  Language: English\nArticle Type:BFN\n[Text] Ri...
# 2  Language: Russian\nArticle Type:BFN\n[Report b...
# 3  Language: English\nArticle Type:BFN\n[Text] Ta...
# 4  Language: English\nArticle Type:BFN\n[Text] Ov...
# 5  Language: Russian\nArticle Type:CSO\n[Article ...
# 6  Language: English\nArticle Type:BFN\n[Text] Ge...
# 7  Language: English\nArticle Type:BFN\n[Text] Br...
# 8  Language: German\nArticle Type:BFN\n["a.u."-si...
# 9  Language: English\nArticle Type:BFN\n[Text] Tb...
#
#                                       features     score  rank
# 0   [2.0, 5.0, 0.0, 505.0, 4.0, 126.25, 352.0] -0.571241    52
# 1      [2.0, 3.0, 0.5, 122.0, 4.0, 30.5, 11.0] -0.295548    19
# 2   [2.0, 6.0, 0.25, 674.0, 4.0, 168.5, 109.0] -0.421296    26
# 3    [1.0, 3.0, 0.25, 204.0, 4.0, 51.0, 147.0] -1.240211    84
# 4   [2.0, 10.0, 0.25, 408.0, 4.0, 102.0, 10.0] -0.510256    42
# 5  [2.0, 9.0, 0.0, 1521.0, 4.0, 380.25, 258.0]  0.020096     2
# 6     [2.0, 5.0, 0.25, 370.0, 4.0, 92.5, 66.0] -0.623001    68
# 7      [2.0, 9.0, 0.5, 330.0, 4.0, 82.5, 20.0] -0.487237    35
# 8     [2.0, 5.0, 0.5, 303.0, 4.0, 75.75, 99.0] -0.615631    61
# 9     [2.0, 3.0, 0.5, 149.0, 4.0, 37.25, 24.0] -0.330826    21

# %%
# Weight: Number of times a feature is used in splits.
# Gain: Average improvement in the loss function when the feature is used.
# Cover: Average number of samples affected by splits using the feature.

print(ltr_pipeline[-1].transform)

skle = ltr_pipeline[-1].learner
xgboo = skle.get_booster()
xgboo.feature_names = ["bm25",
                       "TF",
                       "PL2",
                       "term_unique",
                       "term_full",
                       "term_first200",
                       "doc_length",
                       "query_length", 
                       "ratio", 
                       "first_match",
                    ]
# Out:
# <bound method RegressionTransformer.transform of <pyterrier.ltr.LTRTransformer object at 0x39ce7d3a0>>
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[27], line 8
#       5 print(ltr_pipeline[-1].transform)
#       7 skle = ltr_pipeline[-1].learner
# ----> 8 xgboo = skle.get_booster()
#       9 xgboo.feature_names = ["bm25",
#      10                        "TF",
#      11                        "PL2",
#    (...)
#      18                        "first_match",
#      19                     ]
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/sklearn.py:1009, in XGBModel.get_booster(self)
#    1006 if not self.__sklearn_is_fitted__():
#    1007     from sklearn.exceptions import NotFittedError
# -> 1009     raise NotFittedError("need to call fit or load_model beforehand")
#    1010 return self._Booster
#
# NotFittedError: need to call fit or load_model beforehand

# %%
xgb.plot_importance(xgboo,importance_type = "weight")
plt.show()

# %%
xgb.plot_importance(xgboo,importance_type = "gain")
plt.show()

# %%
xgb.plot_importance(xgboo,importance_type = "cover")
plt.show()

# %%
evalution = pt.Experiment([ltr_pipeline],valid_topics,valid_qrels, eval_metrics=["map", "ndcg_cut_10"])
# Out:
# 21:28:58.051 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 651 - U S  ethnic population
# 21:28:58.053 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.056 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.057 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.059 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.061 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.063 [main] INFO org.terrier.querying.LocalManager -- ethnic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@38145825] tags=[firstmatchscore]} popul { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@41330d4f] tags=[firstmatchscore]}
# 21:28:58.066 [main] INFO org.terrier.matching.PostingListManager -- Query 651 with 2 terms has 2 posting lists
# 21:28:58.074 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.076 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.109 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 651 in 58ms - 1000 results retrieved
# 21:28:58.134 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 652 - OIC Balkans 1990s
# 21:28:58.136 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.138 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.139 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.140 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.142 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.143 [main] INFO org.terrier.querying.LocalManager -- oic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1b66c0fb] tags=[firstmatchscore]} balkan { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3e0e1046] tags=[firstmatchscore]} 1990 { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@24c1b2d2] tags=[firstmatchscore]}
# 21:28:58.148 [main] INFO org.terrier.matching.PostingListManager -- Query 652 with 3 terms has 3 posting lists
# 21:28:58.158 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.160 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.191 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 652 in 57ms - 1000 results retrieved
# 21:28:58.216 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 653 - ETA Basque terrorism
# 21:28:58.218 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.219 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.220 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.222 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.224 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.225 [main] INFO org.terrier.querying.LocalManager -- eta { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7dc19a70] tags=[firstmatchscore]} basqu { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@508dec2b] tags=[firstmatchscore]} terror { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1e4f4a5c] tags=[firstmatchscore]}
# 21:28:58.230 [main] INFO org.terrier.matching.PostingListManager -- Query 653 with 3 terms has 3 posting lists
# 21:28:58.234 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.236 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.265 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 653 in 49ms - 1000 results retrieved
# 21:28:58.287 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 654 - same sex schools
# 21:28:58.288 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.290 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.291 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.292 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.296 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.298 [main] INFO org.terrier.querying.LocalManager -- sex { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@37313c65] tags=[firstmatchscore]} school { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@465232e9] tags=[firstmatchscore]}
# 21:28:58.300 [main] INFO org.terrier.matching.PostingListManager -- Query 654 with 2 terms has 2 posting lists
# 21:28:58.308 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.309 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.342 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 654 in 55ms - 1000 results retrieved
# 21:28:58.367 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 655 - ADD diagnosis treatment
# 21:28:58.369 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.372 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.373 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.373 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.378 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.381 [main] INFO org.terrier.querying.LocalManager -- add { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@798162bc] tags=[firstmatchscore]} diagnosi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1df8da7a] tags=[firstmatchscore]} treatment { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@23941fb4] tags=[firstmatchscore]}
# 21:28:58.386 [main] INFO org.terrier.matching.PostingListManager -- Query 655 with 3 terms has 3 posting lists
# 21:28:58.392 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.397 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.431 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 655 in 64ms - 1000 results retrieved
# 21:28:58.453 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 656 - lead poisoning children
# 21:28:58.455 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.457 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.458 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.460 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.465 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.467 [main] INFO org.terrier.querying.LocalManager -- lead { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7486b455] tags=[firstmatchscore]} poison { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@660acfb] tags=[firstmatchscore]} children { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5d908d47] tags=[firstmatchscore]}
# 21:28:58.471 [main] INFO org.terrier.matching.PostingListManager -- Query 656 with 3 terms has 3 posting lists
# 21:28:58.482 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.484 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.516 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 656 in 63ms - 1000 results retrieved
# 21:28:58.537 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 657 - school prayer banned
# 21:28:58.538 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.539 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.542 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.544 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.546 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.549 [main] INFO org.terrier.querying.LocalManager -- school { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5efa40fe] tags=[firstmatchscore]} prayer { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1f9f6368] tags=[firstmatchscore]} ban { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1c9b0314] tags=[firstmatchscore]}
# 21:28:58.551 [main] INFO org.terrier.matching.PostingListManager -- Query 657 with 3 terms has 3 posting lists
# 21:28:58.560 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.561 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.589 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 657 in 52ms - 1000 results retrieved
# 21:28:58.613 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 658 - teenage pregnancy
# 21:28:58.615 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.616 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.618 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.619 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.620 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.622 [main] INFO org.terrier.querying.LocalManager -- teenag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@45385f75] tags=[firstmatchscore]} pregnanc { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@49c90a9c] tags=[firstmatchscore]}
# 21:28:58.624 [main] INFO org.terrier.matching.PostingListManager -- Query 658 with 2 terms has 2 posting lists
# 21:28:58.627 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.629 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.660 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 658 in 47ms - 1000 results retrieved
# 21:28:58.683 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 659 - cruise health safety
# 21:28:58.685 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.687 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.688 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.690 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.691 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.693 [main] INFO org.terrier.querying.LocalManager -- cruis { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2d29b4ee] tags=[firstmatchscore]} health { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@69ee81fc] tags=[firstmatchscore]} safeti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6e2aa843] tags=[firstmatchscore]}
# 21:28:58.697 [main] INFO org.terrier.matching.PostingListManager -- Query 659 with 3 terms has 3 posting lists
# 21:28:58.704 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.706 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.735 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 659 in 52ms - 1000 results retrieved
# 21:28:58.755 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 660 - whale watching California
# 21:28:58.756 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.760 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.760 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.764 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.766 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.767 [main] INFO org.terrier.querying.LocalManager -- whale { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6f36c2f0] tags=[firstmatchscore]} watch { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@f58853c] tags=[firstmatchscore]} california { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1224144a] tags=[firstmatchscore]}
# 21:28:58.770 [main] INFO org.terrier.matching.PostingListManager -- Query 660 with 3 terms has 3 posting lists
# 21:28:58.777 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.780 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.809 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 660 in 54ms - 1000 results retrieved
# 21:28:58.830 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 661 - melanoma treatment causes
# 21:28:58.833 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.837 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.839 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.841 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.846 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.848 [main] INFO org.terrier.querying.LocalManager -- melanoma { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@29f7cefd] tags=[firstmatchscore]} treatment { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@700fb871] tags=[firstmatchscore]} caus { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3b35a229] tags=[firstmatchscore]}
# 21:28:58.854 [main] INFO org.terrier.matching.PostingListManager -- Query 661 with 3 terms has 3 posting lists
# 21:28:58.863 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.867 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.897 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 661 in 67ms - 1000 results retrieved
# 21:28:58.919 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 662 - telemarketer protection
# 21:28:58.921 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:58.923 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:58.924 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:58.925 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:58.928 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:58.930 [main] INFO org.terrier.querying.LocalManager -- telemarket { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@9816741] tags=[firstmatchscore]} protect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1e16c0aa] tags=[firstmatchscore]}
# 21:28:58.933 [main] INFO org.terrier.matching.PostingListManager -- Query 662 with 2 terms has 2 posting lists
# 21:28:58.940 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:58.941 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:58.971 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 662 in 52ms - 1000 results retrieved
# 21:28:58.998 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 663 - Agent Orange exposure
# 21:28:59.000 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.001 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.002 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.004 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.004 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.007 [main] INFO org.terrier.querying.LocalManager -- agent { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@13d73f29] tags=[firstmatchscore]} orang { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@565f390] tags=[firstmatchscore]} exposur { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7dc3712] tags=[firstmatchscore]}
# 21:28:59.010 [main] INFO org.terrier.matching.PostingListManager -- Query 663 with 3 terms has 3 posting lists
# 21:28:59.022 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.053 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.096 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 663 in 98ms - 1000 results retrieved
# 21:28:59.119 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 664 - American Indian Museum
# 21:28:59.120 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.122 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.124 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.126 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.128 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.130 [main] INFO org.terrier.querying.LocalManager -- american { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2f67a4d3] tags=[firstmatchscore]} indian { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5e3f861] tags=[firstmatchscore]} museum { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2fb0623e] tags=[firstmatchscore]}
# 21:28:59.133 [main] INFO org.terrier.matching.PostingListManager -- Query 664 with 3 terms has 3 posting lists
# 21:28:59.141 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.143 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.173 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 664 in 54ms - 1000 results retrieved
# 21:28:59.194 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 665 - poverty Africa sub Sahara
# 21:28:59.196 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.198 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.200 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.202 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.203 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.205 [main] INFO org.terrier.querying.LocalManager -- poverti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@49b2a47d] tags=[firstmatchscore]} africa { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5be1d0a4] tags=[firstmatchscore]} sub { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@415b0b49] tags=[firstmatchscore]} sahara { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6d5620ce] tags=[firstmatchscore]}
# 21:28:59.209 [main] INFO org.terrier.matching.PostingListManager -- Query 665 with 4 terms has 4 posting lists
# 21:28:59.216 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.218 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.248 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 665 in 54ms - 1000 results retrieved
# 21:28:59.268 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 666 - Thatcher resignation impact
# 21:28:59.270 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.270 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.272 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.273 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.275 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.277 [main] INFO org.terrier.querying.LocalManager -- thatcher { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@311bf055] tags=[firstmatchscore]} resign { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@642a7222] tags=[firstmatchscore]} impact { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7d322cad] tags=[firstmatchscore]}
# 21:28:59.279 [main] INFO org.terrier.matching.PostingListManager -- Query 666 with 3 terms has 3 posting lists
# 21:28:59.287 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.289 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.319 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 666 in 51ms - 1000 results retrieved
# 21:28:59.339 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 667 - unmarried partner households
# 21:28:59.341 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.344 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.347 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.349 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.351 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.352 [main] INFO org.terrier.querying.LocalManager -- unmarri { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@21be3395] tags=[firstmatchscore]} partner { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4f49f6af] tags=[firstmatchscore]} household { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@78452606] tags=[firstmatchscore]}
# 21:28:59.356 [main] INFO org.terrier.matching.PostingListManager -- Query 667 with 3 terms has 3 posting lists
# 21:28:59.365 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.367 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.396 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 667 in 57ms - 1000 results retrieved
# 21:28:59.418 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 668 - poverty  disease
# 21:28:59.420 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.422 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.423 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.427 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.428 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.432 [main] INFO org.terrier.querying.LocalManager -- poverti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@147e2ae7] tags=[firstmatchscore]} diseas { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@448c8166] tags=[firstmatchscore]}
# 21:28:59.434 [main] INFO org.terrier.matching.PostingListManager -- Query 668 with 2 terms has 2 posting lists
# 21:28:59.438 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.439 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.468 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 668 in 50ms - 1000 results retrieved
# 21:28:59.490 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 669 - Islamic Revolution
# 21:28:59.493 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.494 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.496 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.498 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.500 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.501 [main] INFO org.terrier.querying.LocalManager -- islam { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4470fbd6] tags=[firstmatchscore]} revolut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@15d49048] tags=[firstmatchscore]}
# 21:28:59.503 [main] INFO org.terrier.matching.PostingListManager -- Query 669 with 2 terms has 2 posting lists
# 21:28:59.506 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.510 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.540 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 669 in 50ms - 1000 results retrieved
# 21:28:59.562 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 670 - U S  elections apathy
# 21:28:59.565 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.567 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.569 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.571 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.573 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.574 [main] INFO org.terrier.querying.LocalManager -- elect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7098b907] tags=[firstmatchscore]} apathi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@503f91c3] tags=[firstmatchscore]}
# 21:28:59.577 [main] INFO org.terrier.matching.PostingListManager -- Query 670 with 2 terms has 2 posting lists
# 21:28:59.586 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.588 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.622 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 670 in 60ms - 1000 results retrieved
# 21:28:59.643 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 671 - Salvation Army benefits
# 21:28:59.645 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.648 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.650 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.652 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.653 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.654 [main] INFO org.terrier.querying.LocalManager -- salvat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@13526e59] tags=[firstmatchscore]} armi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2235eaab] tags=[firstmatchscore]} benefit { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@17503f6b] tags=[firstmatchscore]}
# 21:28:59.658 [main] INFO org.terrier.matching.PostingListManager -- Query 671 with 3 terms has 3 posting lists
# 21:28:59.668 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.670 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.700 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 671 in 57ms - 1000 results retrieved
# 21:28:59.723 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 672 - NRA membership profile
# 21:28:59.725 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.727 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.730 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.735 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.736 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.752 [main] INFO org.terrier.querying.LocalManager -- nra { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3bcd05cb] tags=[firstmatchscore]} membership { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3b6d844d] tags=[firstmatchscore]} profil { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@36804139] tags=[firstmatchscore]}
# 21:28:59.767 [main] INFO org.terrier.matching.PostingListManager -- Query 672 with 3 terms has 3 posting lists
# 21:28:59.775 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.781 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.834 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 672 in 111ms - 1000 results retrieved
# 21:28:59.858 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 673 - Soviet withdrawal Afghanistan
# 21:28:59.861 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.862 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.868 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.870 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.872 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.873 [main] INFO org.terrier.querying.LocalManager -- soviet { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@20bd8be5] tags=[firstmatchscore]} withdraw { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@730d2164] tags=[firstmatchscore]} afghanistan { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@24959ca4] tags=[firstmatchscore]}
# 21:28:59.880 [main] INFO org.terrier.matching.PostingListManager -- Query 673 with 3 terms has 3 posting lists
# 21:28:59.886 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.888 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:28:59.920 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 673 in 62ms - 1000 results retrieved
# 21:28:59.943 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 674 - Greenpeace prosecuted
# 21:28:59.949 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:28:59.951 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:28:59.954 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:28:59.956 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:28:59.957 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:28:59.962 [main] INFO org.terrier.querying.LocalManager -- greenpeac { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@10289886] tags=[firstmatchscore]} prosecut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5c86dbc5] tags=[firstmatchscore]}
# 21:28:59.969 [main] INFO org.terrier.matching.PostingListManager -- Query 674 with 2 terms has 2 posting lists
# 21:28:59.973 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:28:59.976 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.049 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 674 in 106ms - 1000 results retrieved
# 21:29:00.089 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 675 - Olympics training swimming
# 21:29:00.093 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.096 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.100 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.102 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.105 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.108 [main] INFO org.terrier.querying.LocalManager -- olymp { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@461ad730] tags=[firstmatchscore]} train { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@4ee203eb] tags=[firstmatchscore]} swim { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1a5a4e19] tags=[firstmatchscore]}
# 21:29:00.114 [main] INFO org.terrier.matching.PostingListManager -- Query 675 with 3 terms has 3 posting lists
# 21:29:00.125 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.132 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.189 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 675 in 100ms - 1000 results retrieved
# 21:29:00.218 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 676 - poppy cultivation
# 21:29:00.220 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.222 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.224 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.227 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.230 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.233 [main] INFO org.terrier.querying.LocalManager -- poppi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7068e664] tags=[firstmatchscore]} cultiv { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@60db1c0e] tags=[firstmatchscore]}
# 21:29:00.236 [main] INFO org.terrier.matching.PostingListManager -- Query 676 with 2 terms has 2 posting lists
# 21:29:00.240 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.243 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.295 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 676 in 77ms - 1000 results retrieved
# 21:29:00.323 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 677 - Leaning Tower of Pisa
# 21:29:00.326 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.330 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.333 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.336 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.337 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.339 [main] INFO org.terrier.querying.LocalManager -- lean { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3e78b6a5] tags=[firstmatchscore]} tower { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@769a1df5] tags=[firstmatchscore]} pisa { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@41f69e84] tags=[firstmatchscore]}
# 21:29:00.345 [main] INFO org.terrier.matching.PostingListManager -- Query 677 with 3 terms has 3 posting lists
# 21:29:00.349 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.352 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.387 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 677 in 64ms - 1000 results retrieved
# 21:29:00.412 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 678 - joint custody impact
# 21:29:00.416 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.418 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.420 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.422 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.426 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.429 [main] INFO org.terrier.querying.LocalManager -- joint { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7975d1d8] tags=[firstmatchscore]} custodi { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2438dcd] tags=[firstmatchscore]} impact { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@24105dc5] tags=[firstmatchscore]}
# 21:29:00.436 [main] INFO org.terrier.matching.PostingListManager -- Query 678 with 3 terms has 3 posting lists
# 21:29:00.451 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.454 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.491 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 678 in 79ms - 1000 results retrieved
# 21:29:00.517 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 679 - opening adoption records
# 21:29:00.519 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.520 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.521 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.523 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.525 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.527 [main] INFO org.terrier.querying.LocalManager -- open { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5167f57d] tags=[firstmatchscore]} adopt { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@64b0598] tags=[firstmatchscore]} record { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@18f8cd79] tags=[firstmatchscore]}
# 21:29:00.534 [main] INFO org.terrier.matching.PostingListManager -- Query 679 with 3 terms has 3 posting lists
# 21:29:00.550 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.552 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.595 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 679 in 78ms - 1000 results retrieved
# 21:29:00.638 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 680 - immigrants Spanish school
# 21:29:00.643 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.647 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.650 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.652 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.653 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.655 [main] INFO org.terrier.querying.LocalManager -- immigr { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@3e2055d6] tags=[firstmatchscore]} spanish { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@50029372] tags=[firstmatchscore]} school { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@e3b3b2f] tags=[firstmatchscore]}
# 21:29:00.658 [main] INFO org.terrier.matching.PostingListManager -- Query 680 with 3 terms has 3 posting lists
# 21:29:00.667 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.668 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.698 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 680 in 60ms - 1000 results retrieved
# 21:29:00.720 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 681 - wind power location
# 21:29:00.722 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.724 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.727 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.729 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.731 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.734 [main] INFO org.terrier.querying.LocalManager -- wind { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@50f6ac94] tags=[firstmatchscore]} power { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@6cc4cdb9] tags=[firstmatchscore]} locat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@28194a50] tags=[firstmatchscore]}
# 21:29:00.737 [main] INFO org.terrier.matching.PostingListManager -- Query 681 with 3 terms has 3 posting lists
# 21:29:00.749 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.752 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.782 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 681 in 62ms - 1000 results retrieved
# 21:29:00.804 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 682 - adult immigrants English
# 21:29:00.807 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.810 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.812 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.814 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.817 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.818 [main] INFO org.terrier.querying.LocalManager -- adult { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@7f2cfe3f] tags=[firstmatchscore]} immigr { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@1a5b6f42] tags=[firstmatchscore]} english { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@5038d0b5] tags=[firstmatchscore]}
# 21:29:00.821 [main] INFO org.terrier.matching.PostingListManager -- Query 682 with 3 terms has 3 posting lists
# 21:29:00.832 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.834 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.867 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 682 in 63ms - 1000 results retrieved
# 21:29:00.892 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 683 - Czechoslovakia breakup
# 21:29:00.894 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:00.895 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:00.897 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:00.899 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:00.901 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:00.903 [main] INFO org.terrier.querying.LocalManager -- czechoslovakia { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@32115b28] tags=[firstmatchscore]} breakup { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.BM25@2ad48653] tags=[firstmatchscore]}
# 21:29:00.906 [main] INFO org.terrier.matching.PostingListManager -- Query 683 with 2 terms has 2 posting lists
# 21:29:00.909 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:00.913 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:00.943 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 683 in 51ms - 1000 results retrieved
# 21:29:00.965 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 684 - part time benefits
# ...
# 21:29:06.498 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:06.500 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:06.504 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:06.507 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:06.510 [main] INFO org.terrier.querying.LocalManager -- colleg { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5e21e98f] tags=[firstmatchscore]} educ { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@51a9ad5e] tags=[firstmatchscore]} advantag { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5f20155b] tags=[firstmatchscore]}
# 21:29:06.513 [main] INFO org.terrier.matching.PostingListManager -- Query 690 with 3 terms has 3 posting lists
# 21:29:06.530 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:06.538 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:06.683 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 690 in 189ms - 1000 results retrieved
# 21:29:06.730 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 691 - clear cutting forests
# 21:29:06.735 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:06.740 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:06.742 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:06.744 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:06.746 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:06.748 [main] INFO org.terrier.querying.LocalManager -- clear { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@72ade7e3] tags=[firstmatchscore]} cut { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@239105a8] tags=[firstmatchscore]} forest { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@3fce8fd9] tags=[firstmatchscore]}
# 21:29:06.755 [main] INFO org.terrier.matching.PostingListManager -- Query 691 with 3 terms has 3 posting lists
# 21:29:06.777 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:06.780 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:06.824 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 691 in 94ms - 1000 results retrieved
# 21:29:06.847 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 692 - prostate cancer detection treatment
# 21:29:06.849 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:06.852 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:06.855 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:06.857 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:06.860 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:06.861 [main] INFO org.terrier.querying.LocalManager -- prostat { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@609bcfb6] tags=[firstmatchscore]} cancer { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7d94beb9] tags=[firstmatchscore]} detect { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@560348e6] tags=[firstmatchscore]} treatment { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@1df8b5b8] tags=[firstmatchscore]}
# 21:29:06.865 [main] INFO org.terrier.matching.PostingListManager -- Query 692 with 4 terms has 4 posting lists
# 21:29:06.874 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:06.876 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:06.906 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 692 in 59ms - 1000 results retrieved
# 21:29:06.931 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 693 - newspapers electronic media
# 21:29:06.933 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:06.937 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:06.940 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:06.943 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:06.944 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:06.946 [main] INFO org.terrier.querying.LocalManager -- newspap { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@23202fce] tags=[firstmatchscore]} electron { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7b993c65] tags=[firstmatchscore]} media { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@37911f88] tags=[firstmatchscore]}
# 21:29:06.952 [main] INFO org.terrier.matching.PostingListManager -- Query 693 with 3 terms has 3 posting lists
# 21:29:06.965 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:06.968 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.007 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 693 in 76ms - 1000 results retrieved
# 21:29:07.052 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 694 - compost pile
# 21:29:07.079 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.082 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.086 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.090 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.092 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.095 [main] INFO org.terrier.querying.LocalManager -- compost { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@6f1c29b7] tags=[firstmatchscore]} pile { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4d6025c5] tags=[firstmatchscore]}
# 21:29:07.098 [main] INFO org.terrier.matching.PostingListManager -- Query 694 with 2 terms has 2 posting lists
# 21:29:07.101 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.108 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.153 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 694 in 101ms - 1000 results retrieved
# 21:29:07.182 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 695 - white collar crime sentence
# 21:29:07.184 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.186 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.191 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.193 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.194 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.196 [main] INFO org.terrier.querying.LocalManager -- white { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@7f284218] tags=[firstmatchscore]} collar { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@407a7f2a] tags=[firstmatchscore]} crime { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4ea5b703] tags=[firstmatchscore]} sentenc { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@2a7ed1f] tags=[firstmatchscore]}
# 21:29:07.200 [main] INFO org.terrier.matching.PostingListManager -- Query 695 with 4 terms has 4 posting lists
# 21:29:07.212 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.213 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.246 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 695 in 64ms - 1000 results retrieved
# 21:29:07.274 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 696 - safety plastic surgery
# 21:29:07.276 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.278 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.279 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.282 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.283 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.285 [main] INFO org.terrier.querying.LocalManager -- safeti { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@3fa247d1] tags=[firstmatchscore]} plastic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@2cb2fc20] tags=[firstmatchscore]} surgeri { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4f4c4b1a] tags=[firstmatchscore]}
# 21:29:07.292 [main] INFO org.terrier.matching.PostingListManager -- Query 696 with 3 terms has 3 posting lists
# 21:29:07.298 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.302 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.341 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 696 in 67ms - 1000 results retrieved
# 21:29:07.414 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 697 - air traffic controller
# 21:29:07.430 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.432 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.436 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.440 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.442 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.444 [main] INFO org.terrier.querying.LocalManager -- air { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@723e88f9] tags=[firstmatchscore]} traffic { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@5f0fd5a0] tags=[firstmatchscore]} control { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@64e7619d] tags=[firstmatchscore]}
# 21:29:07.447 [main] INFO org.terrier.matching.PostingListManager -- Query 697 with 3 terms has 3 posting lists
# 21:29:07.467 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.468 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.501 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 697 in 87ms - 1000 results retrieved
# 21:29:07.524 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 698 - literacy rates Africa
# 21:29:07.526 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.528 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.530 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.533 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.535 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.539 [main] INFO org.terrier.querying.LocalManager -- literaci { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@495ee280] tags=[firstmatchscore]} rate { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4fa1c212] tags=[firstmatchscore]} africa { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@6ea2bc93] tags=[firstmatchscore]}
# 21:29:07.544 [main] INFO org.terrier.matching.PostingListManager -- Query 698 with 3 terms has 3 posting lists
# 21:29:07.557 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.559 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.592 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 698 in 68ms - 1000 results retrieved
# 21:29:07.612 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 699 - term limits
# 21:29:07.614 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.618 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.620 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.625 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.626 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.628 [main] INFO org.terrier.querying.LocalManager -- term { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@3116c353] tags=[firstmatchscore]} limit { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@f627d13] tags=[firstmatchscore]}
# 21:29:07.630 [main] INFO org.terrier.matching.PostingListManager -- Query 699 with 2 terms has 2 posting lists
# 21:29:07.656 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.658 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.686 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 699 in 74ms - 1000 results retrieved
# 21:29:07.716 [main] INFO org.terrier.querying.LocalManager -- Starting to execute query 700 - gasoline tax U S
# 21:29:07.719 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLParser
# 21:29:07.722 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToControls
# 21:29:07.741 [main] INFO org.terrier.querying.LocalManager -- running process TerrierQLToMatchingQueryTerms
# 21:29:07.744 [main] INFO org.terrier.querying.LocalManager -- running process ApplyTermPipeline(termpipelines=Stopwords,PorterStemmer)
# 21:29:07.765 [main] INFO org.terrier.querying.LocalManager -- running process ApplyLocalMatching
# 21:29:07.770 [main] INFO org.terrier.querying.LocalManager -- gasolin { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@4e928fbf] tags=[firstmatchscore]} tax { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.PL2@352ff4da] tags=[firstmatchscore]}
# 21:29:07.781 [main] INFO org.terrier.matching.PostingListManager -- Query 700 with 2 terms has 2 posting lists
# 21:29:07.795 [main] INFO org.terrier.querying.LocalManager -- running process PostFilterProcess
# 21:29:07.811 [main] INFO org.terrier.querying.LocalManager -- running process SimpleDecorateProcess
# 21:29:07.843 [main] INFO org.terrier.querying.LocalManager -- Finished executing query 700 in 127ms - 1000 results retrieved

# %%
print(evalution)
# Out:
#                                                 name       map  ndcg_cut_10
# 0  (<pyterrier._ops.SetUnion object at 0x0000028C...  0.174048     0.303114

# %%
df_eval = pd.DataFrame(evalution)
excel_path = "owi_evaluation_results.xlsx"
sheet_name = "owi_Results"

if os.path.exists(excel_path):
    existing = pd.read_excel(excel_path, sheet_name=sheet_name)
    combined = pd.concat([existing, df_eval], ignore_index=True)
    combined.to_excel(excel_path, sheet_name=sheet_name, index=False)
else:
    df_eval.to_excel(excel_path, sheet_name=sheet_name, index=False)

print(eval)
